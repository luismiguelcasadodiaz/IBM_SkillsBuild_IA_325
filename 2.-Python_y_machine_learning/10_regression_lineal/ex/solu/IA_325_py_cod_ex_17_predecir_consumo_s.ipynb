# %% [markdown]
# <a href="https://colab.research.google.com/github/luismiguelcasadodiaz/IBM_SkillsBuild_IA_325/blob/main/IA_325_py_cod_ex_17_s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predecir consumo energético de satélites
#
#
# Una agencia espacial quiere entender mejor cómo varía el **consumo energético diario** de sus satélites dependiendo de la **duración de su misión**.
#
# Te han pedido que analices esta relación utilizando **datos simulados**, y que desarrolles un modelo que permita:
#
# + Generar una muestra de satélites con características realistas.
# + Calcular una **nueva métrica**: la **eficiencia energética** del satélite.
# + Aplicar un modelo de **regresión lineal** para predecir el consumo diario a partir de la duración de la misión.
# + Visualizar los resultados para facilitar la toma de decisiones.
#
#
# ##  Actividades a realizar
#
# ### 1. Crear una clase Satellite
#
# Esta clase debe representar un satélite individual con los siguientes atributos:
#
# + duracion_mision (en días)
# + paneles_sol (superficie total de paneles solares en m²)
# + carga_util (peso de instrumentos y sensores en kg)
# + consumo_diario (energía consumida por día en kWh)
#
# <br>
# <br>
#
# ###  2. Generar datos sintéticos con SatelliteDatasetGenerator
#
# Esta clase debe generar N satélites simulados (por defecto 300), con los siguientes criterios:
#
# + duracion_mision: aleatorio entre 100 y 1000 días.
# + paneles_sol: aleatorio entre 10 y 100 m².
# + carga_util: aleatorio entre 200 y 2000 kg.
# + consumo_diario: calculado con la fórmula:
# consumo_diario=5+(0.01⋅duracion_mision)+(0.002⋅carga_util)+ruido_normal
# Donde ruido_normal es una perturbación aleatoria generada con np.random.normal(0, 1) para hacer los datos más realistas.
#
#
# <br>
# <br>
#
# ### 3. Procesar los datos con SatelliteDataProcessor
#
# Convierte la lista de objetos Satellite en un DataFrame de pandas, y añade una columna nueva: Esta métrica mide cuánto **consume el satélite por cada metro cuadrado de panel solar**.
# <br>
# <br>
#
#
# ### 4. Aplicar regresión lineal con EnergyConsumptionRegressor
#
# Esta clase debe aplicar el modelo de regresión lineal para predecir el consumo energético a partir de la duración de la misión. Debes:
#
# Entrenar el modelo con duracion_mision_dias como entrada (X) y consumo_diario como salida (y).
#
# Calcular el R² del modelo (r2_score) y mostrar los coeficientes:
#
# y_pred=(coef⋅duracion_mision)+intercepto
#
# <br>
# <br>
#
# ### 5. Visualizar los resultados con SatellitePlotter
#
# Muestra un gráfico con:
#
# + Puntos dispersos: consumo diario vs. duración de la misión.
# + Color por carga útil (usa un mapa de color viridis).
# + Línea de regresión en rojo.
#
# <br>
# <br>
#
# ### 6. Ejecutar todo con la clase SatelliteAnalysisExample
#
# Una vez que has desarrollado las clases anteriores para generar, procesar, modelar y visualizar los datos, el último paso es integrar todo en una clase orquestadora que automatice el análisis completo.Esta clase debe encargarse de:
#
# + Generar los datos: usando la clase SatelliteDatasetGenerator.
# + Procesarlos: con SatelliteDataProcessor, que además de convertir la lista a DataFrame, añade la columna de eficiencia.
# + Aplicar regresión: usando EnergyConsumptionRegressor para entrenar el modelo con la duración de la misión como predictor.
# + Evaluar el modelo: imprimiendo el coeficiente de regresión, el intercepto y el R², que indica qué tan bien se ajusta el modelo a los datos.
# + Visualizar los resultados: con SatellitePlotter, mostrando una gráfica clara con los datos y la predicción lineal
#
#
#
#
# ## Ejemplo de uso
#
# example = SatelliteAnalysisExample()
# example.run()
#
#
# Salida esperada
#
# 📈 Modelo: y = 0.0103 * x + 7.06
# 🔍 R² del modelo: 0.7780

# %% [markdown]
# ## Importacion de librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# 1. Crear una clase Satellite
#
# Esta clase debe representar un satélite individual con los siguientes atributos:
#
# + duracion_mision (en días)
# + paneles_sol (superficie total de paneles solares en m²)
# + carga_util (peso de instrumentos y sensores en kg)
# + consumo_diario (energía consumida por día en kWh)

# %%
class Satellite:
  def __init__(self, duracion_mision, paneles_sol, carga_util, consumo_diario):
    self.duracion_mision_dias = duracion_mision
    self.paneles_sol_m2 =paneles_sol
    self.carga_util_kg = carga_util
    self.consumo_diario_kWh = consumo_diario

  def __str__(self):
    resultado = f"Duración de la misión: {self.duracion_mision_dias} días\n"
    resultado += f"Superficie de paneles solares: {self.paneles_sol_m2} m²\n"
    resultado += f"Carga útil: {self.carga_util_kg} kg\n"
    resultado += f"Consumo diario: {self.consumo_diario_kWh} kWh\n"
    return resultado

  def get_duracion(self):
    return  self.duracion_mision_dias

  def get_paneles_sol(self):
    return self.paneles_sol_m2

  def get_carga_util(self):
    return self.carga_util_kg

  def get_consumo_diario(self):
    return self.consumo_diario_kWh

  def set_duracion(self, duracion):
    self.duracion_mision_dias = duracion

  def set_paneles_sol(self, paneles_sol):
    self.paneles_sol_m2 = paneles_sol

  def set_carga_util(self, carga_util):
    self.carga_util_kg = carga_util

  def set_consumo_diario(self, consumo_diario):
    self.consumo_diario_kWh = consumo_diario

# %% [markdown]
# #### tests clase Satellite

# %%
sat1 = Satellite(100, 50, 150, 10)
print(sat1)
print(vars(sat1).values())
# Out:
# Duración de la misión: 100 días
# Superficie de paneles solares: 50 m²
# Carga útil: 150 kg
# Consumo diario: 10 kWh
#
# dict_values([100, 50, 150, 10])

# %% [markdown]
# 2. Generar datos sintéticos con SatelliteDatasetGenerator
# Esta clase debe generar N satélites simulados (por defecto 300), con los siguientes criterios:
#
# + duracion_mision: aleatorio entre 100 y 1000 días.
# + paneles_sol: aleatorio entre 10 y 100 m².
# + carga_util: aleatorio entre 200 y 2000 kg.
# + consumo_diario: calculado con la fórmula: consumo_diario=5+(0.01⋅duracion_mision)+(0.002⋅carga_util)+ruido_normal Donde ruido_normal es una perturbación aleatoria generada con np.random.normal(0, 1) para hacer los datos más realistas.

# %%
class SatelliteDatasetGenerator:
  def __init__ (self, n = 300):
    self.rng = np.random.default_rng(42)
    self.n = n

  def _generate_satellite(self):
    dur = self.rng.integers(100, 1000)
    pan = self.rng.integers(10, 100)
    car = self.rng.integers(200, 2000)
    con = 5 + (0.01 * dur) + (0.002 * car) + self.rng.normal(0, 1)
    return Satellite(dur, pan, car, con)

  def generate(self):
    return [self._generate_satellite() for _ in range(self.n)]

# %% [markdown]
# #### test SatelliteDatasetGenerator

# %%
ds1 = SatelliteDatasetGenerator()
satelites = ds1.generate()
for satellite in satelites:
  print(satellite)
# Out:
# Duración de la misión: 180 días
# Superficie de paneles solares: 79 m²
# Carga útil: 1378 kg
# Consumo diario: 10.306451195806458 kWh
#
# Duración de la misión: 494 días
# Superficie de paneles solares: 17 m²
# Carga útil: 1455 kg
# Consumo diario: 10.898964811346165 kWh
#
# Duración de la misión: 573 días
# Superficie de paneles solares: 97 m²
# Carga útil: 1524 kg
# Consumo diario: 13.461757407656417 kWh
#
# Duración de la misión: 785 días
# Superficie de paneles solares: 56 m²
# Carga útil: 430 kg
# Consumo diario: 12.85695607242642 kWh
#
# Duración de la misión: 550 días
# Superficie de paneles solares: 43 m²
# Carga útil: 528 kg
# Consumo diario: 11.622030697561216 kWh
#
# Duración de la misión: 934 días
# Superficie de paneles solares: 46 m²
# Carga útil: 1680 kg
# Consumo diario: 18.167509342252046 kWh
#
# Duración de la misión: 505 días
# Superficie de paneles solares: 30 m²
# Carga útil: 365 kg
# Consumo diario: 9.821117399171003 kWh
#
# Duración de la misión: 599 días
# Superficie de paneles solares: 87 m²
# Carga útil: 1689 kg
# Consumo diario: 14.318074089013747 kWh
#
# Duración de la misión: 248 días
# Superficie de paneles solares: 78 m²
# Carga útil: 1460 kg
# Consumo diario: 11.622541338674031 kWh
#
# Duración de la misión: 419 días
# Superficie de paneles solares: 50 m²
# Carga útil: 1807 kg
# Consumo diario: 12.375672177836895 kWh
#
# Duración de la misión: 783 días
# Superficie de paneles solares: 27 m²
# Carga útil: 855 kg
# Consumo diario: 14.905444064364078 kWh
#
# Duración de la misión: 520 días
# Superficie de paneles solares: 59 m²
# Carga útil: 477 kg
# Consumo diario: 11.584821003007882 kWh
#
# Duración de la misión: 930 días
# Superficie de paneles solares: 77 m²
# Carga útil: 859 kg
# Consumo diario: 15.505757270928463 kWh
#
# Duración de la misión: 970 días
# Superficie de paneles solares: 91 m²
# Carga útil: 866 kg
# Consumo diario: 17.047979422575498 kWh
#
# Duración de la misión: 816 días
# Superficie de paneles solares: 27 m²
# Carga útil: 1033 kg
# Consumo diario: 14.38584352303747 kWh
#
# Duración de la misión: 216 días
# Superficie de paneles solares: 39 m²
# Carga útil: 608 kg
# Consumo diario: 9.0265927878247 kWh
#
# Duración de la misión: 946 días
# Superficie de paneles solares: 49 m²
# Carga útil: 489 kg
# Consumo diario: 14.266804829637463 kWh
#
# Duración de la misión: 849 días
# Superficie de paneles solares: 18 m²
# Carga útil: 762 kg
# Consumo diario: 14.348490292711306 kWh
#
# Duración de la misión: 491 días
# Superficie de paneles solares: 82 m²
# Carga útil: 1715 kg
# Consumo diario: 13.558688596729013 kWh
#
# Duración de la misión: 448 días
# Superficie de paneles solares: 31 m²
# Carga útil: 1428 kg
# Consumo diario: 12.559595548774682 kWh
#
# Duración de la misión: 849 días
# Superficie de paneles solares: 27 m²
# Carga útil: 1648 kg
# Consumo diario: 17.075119398689985 kWh
#
# Duración de la misión: 106 días
# Superficie de paneles solares: 80 m²
# Carga útil: 1396 kg
# Consumo diario: 7.394844180144334 kWh
#
# Duración de la misión: 349 días
# Superficie de paneles solares: 80 m²
# Carga útil: 1200 kg
# Consumo diario: 10.25112215175666 kWh
#
# Duración de la misión: 513 días
# Superficie de paneles solares: 13 m²
# Carga útil: 451 kg
# Consumo diario: 12.526941311234394 kWh
#
# Duración de la misión: 495 días
# Superficie de paneles solares: 70 m²
# Carga útil: 1377 kg
# Consumo diario: 11.021130228384195 kWh
#
# Duración de la misión: 523 días
# Superficie de paneles solares: 17 m²
# Carga útil: 1576 kg
# Consumo diario: 13.544753065105008 kWh
#
# Duración de la misión: 608 días
# Superficie de paneles solares: 59 m²
# Carga útil: 363 kg
# Consumo diario: 12.599347235199927 kWh
#
# Duración de la misión: 603 días
# Superficie de paneles solares: 64 m²
# Carga útil: 255 kg
# Consumo diario: 11.077648207335434 kWh
#
# Duración de la misión: 984 días
# Superficie de paneles solares: 29 m²
# Carga útil: 697 kg
# Consumo diario: 14.95831367666208 kWh
#
# Duración de la misión: 467 días
# Superficie de paneles solares: 13 m²
# Carga útil: 621 kg
# Consumo diario: 9.992547713998388 kWh
#
# Duración de la misión: 870 días
# Superficie de paneles solares: 35 m²
# Carga útil: 1851 kg
# Consumo diario: 18.09248535406777 kWh
#
# Duración de la misión: 364 días
# Superficie de paneles solares: 21 m²
# Carga útil: 1202 kg
# Consumo diario: 11.202539691076714 kWh
#
# Duración de la misión: 996 días
# Superficie de paneles solares: 69 m²
# Carga útil: 936 kg
# Consumo diario: 17.288775237557413 kWh
#
# Duración de la misión: 465 días
# Superficie de paneles solares: 38 m²
# Carga útil: 500 kg
# Consumo diario: 10.28694615343493 kWh
#
# Duración de la misión: 195 días
# Superficie de paneles solares: 18 m²
# Carga útil: 1588 kg
# Consumo diario: 10.612972480785583 kWh
#
# Duración de la misión: 750 días
# Superficie de paneles solares: 74 m²
# Carga útil: 490 kg
# Consumo diario: 13.492494118727688 kWh
#
# Duración de la misión: 944 días
# Superficie de paneles solares: 23 m²
# Carga útil: 1095 kg
# Consumo diario: 17.295385108972784 kWh
#
# Duración de la misión: 726 días
# Superficie de paneles solares: 24 m²
# Carga útil: 885 kg
# Consumo diario: 13.606701687955846 kWh
#
# Duración de la misión: 715 días
# Superficie de paneles solares: 66 m²
# Carga útil: 1292 kg
# Consumo diario: 13.286887527576912 kWh
#
# Duración de la misión: 425 días
# Superficie de paneles solares: 40 m²
# Carga útil: 412 kg
# Consumo diario: 9.076753172398519 kWh
#
# Duración de la misión: 429 días
# Superficie de paneles solares: 91 m²
# Carga útil: 1091 kg
# Consumo diario: 11.09383744596061 kWh
#
# Duración de la misión: 729 días
# Superficie de paneles solares: 78 m²
# Carga útil: 1944 kg
# Consumo diario: 15.821736028938572 kWh
#
# Duración de la misión: 335 días
# Superficie de paneles solares: 74 m²
# Carga útil: 1620 kg
# Consumo diario: 11.38456244213237 kWh
#
# Duración de la misión: 504 días
# Superficie de paneles solares: 17 m²
# Carga útil: 373 kg
# Consumo diario: 10.446966924099437 kWh
#
# Duración de la misión: 214 días
# Superficie de paneles solares: 51 m²
# Carga útil: 1467 kg
# Consumo diario: 10.508423643545859 kWh
#
# Duración de la misión: 282 días
# Superficie de paneles solares: 82 m²
# Carga útil: 1242 kg
# Consumo diario: 9.709850044303206 kWh
#
# Duración de la misión: 516 días
# Superficie de paneles solares: 87 m²
# Carga útil: 235 kg
# Consumo diario: 10.100507290936198 kWh
#
# Duración de la misión: 782 días
# Superficie de paneles solares: 69 m²
# Carga útil: 977 kg
# Consumo diario: 14.795852145523444 kWh
#
# Duración de la misión: 226 días
# Superficie de paneles solares: 62 m²
# Carga útil: 370 kg
# Consumo diario: 6.976502507378135 kWh
#
# Duración de la misión: 684 días
# Superficie de paneles solares: 78 m²
# Carga útil: 948 kg
# Consumo diario: 13.955996683971765 kWh
#
# Duración de la misión: 261 días
# Superficie de paneles solares: 54 m²
# Carga útil: 538 kg
# Consumo diario: 9.04287105914951 kWh
#
# Duración de la misión: 396 días
# Superficie de paneles solares: 70 m²
# Carga útil: 386 kg
# Consumo diario: 8.543236945677151 kWh
#
# Duración de la misión: 814 días
# Superficie de paneles solares: 25 m²
# Carga útil: 739 kg
# Consumo diario: 14.228190196844233 kWh
#
# Duración de la misión: 932 días
# Superficie de paneles solares: 50 m²
# Carga útil: 824 kg
# Consumo diario: 16.603150946814406 kWh
#
# Duración de la misión: 365 días
# Superficie de paneles solares: 12 m²
# Carga útil: 472 kg
# Consumo diario: 8.57842091879246 kWh
#
# Duración de la misión: 962 días
# Superficie de paneles solares: 52 m²
# Carga útil: 1608 kg
# Consumo diario: 18.674126567894383 kWh
#
# Duración de la misión: 348 días
# Superficie de paneles solares: 53 m²
# Carga útil: 1408 kg
# Consumo diario: 11.710409433275995 kWh
#
# Duración de la misión: 541 días
# Superficie de paneles solares: 24 m²
# Carga útil: 1229 kg
# Consumo diario: 10.735953719268691 kWh
#
# Duración de la misión: 826 días
# Superficie de paneles solares: 34 m²
# Carga útil: 1916 kg
# Consumo diario: 16.676642739820313 kWh
#
# Duración de la misión: 398 días
# Superficie de paneles solares: 86 m²
# Carga útil: 990 kg
# Consumo diario: 10.819209113583616 kWh
#
# Duración de la misión: 427 días
# Superficie de paneles solares: 84 m²
# Carga útil: 217 kg
# Consumo diario: 9.54536516296131 kWh
#
# Duración de la misión: 906 días
# Superficie de paneles solares: 37 m²
# Carga útil: 1197 kg
# Consumo diario: 14.779317055295644 kWh
#
# Duración de la misión: 699 días
# Superficie de paneles solares: 70 m²
# Carga útil: 413 kg
# Consumo diario: 13.096686766951427 kWh
#
# Duración de la misión: 353 días
# Superficie de paneles solares: 75 m²
# Carga útil: 1508 kg
# Consumo diario: 11.676274521472887 kWh
#
# Duración de la misión: 388 días
# Superficie de paneles solares: 19 m²
# Carga útil: 1306 kg
# Consumo diario: 10.307056233582975 kWh
#
# Duración de la misión: 924 días
# Superficie de paneles solares: 31 m²
# Carga útil: 267 kg
# Consumo diario: 14.048773935464247 kWh
#
# Duración de la misión: 592 días
# Superficie de paneles solares: 43 m²
# Carga útil: 757 kg
# Consumo diario: 13.272489203736344 kWh
#
# Duración de la misión: 846 días
# Superficie de paneles solares: 96 m²
# Carga útil: 770 kg
# Consumo diario: 15.931573012874244 kWh
#
# Duración de la misión: 671 días
# Superficie de paneles solares: 36 m²
# Carga útil: 1319 kg
# Consumo diario: 14.307237473864566 kWh
#
# Duración de la misión: 563 días
# Superficie de paneles solares: 99 m²
# Carga útil: 1884 kg
# Consumo diario: 14.84407220148208 kWh
#
# Duración de la misión: 579 días
# Superficie de paneles solares: 14 m²
# Carga útil: 737 kg
# Consumo diario: 10.98606242568038 kWh
#
# Duración de la misión: 491 días
# Superficie de paneles solares: 23 m²
# Carga útil: 1805 kg
# Consumo diario: 15.099091256410434 kWh
#
# Duración de la misión: 861 días
# Superficie de paneles solares: 90 m²
# Carga útil: 602 kg
# Consumo diario: 15.099826139602543 kWh
#
# Duración de la misión: 904 días
# Superficie de paneles solares: 52 m²
# Carga útil: 768 kg
# Consumo diario: 15.795382501363857 kWh
#
# Duración de la misión: 402 días
# Superficie de paneles solares: 69 m²
# Carga útil: 938 kg
# Consumo diario: 11.324756438461613 kWh
#
# Duración de la misión: 436 días
# Superficie de paneles solares: 76 m²
# Carga útil: 1544 kg
# Consumo diario: 12.631234437221906 kWh
#
# Duración de la misión: 104 días
# Superficie de paneles solares: 94 m²
# Carga útil: 1905 kg
# Consumo diario: 11.50092793223125 kWh
#
# Duración de la misión: 316 días
# Superficie de paneles solares: 16 m²
# Carga útil: 1696 kg
# Consumo diario: 11.372480786717398 kWh
#
# Duración de la misión: 772 días
# Superficie de paneles solares: 26 m²
# Carga útil: 860 kg
# Consumo diario: 13.332954317956512 kWh
#
# Duración de la misión: 639 días
# Superficie de paneles solares: 35 m²
# Carga útil: 758 kg
# Consumo diario: 13.549326794689044 kWh
#
# Duración de la misión: 388 días
# Superficie de paneles solares: 97 m²
# Carga útil: 1098 kg
# Consumo diario: 10.912557101475485 kWh
#
# Duración de la misión: 550 días
# Superficie de paneles solares: 94 m²
# Carga útil: 225 kg
# Consumo diario: 12.357481861313715 kWh
#
# Duración de la misión: 351 días
# Superficie de paneles solares: 21 m²
# Carga útil: 232 kg
# Consumo diario: 6.923827898968978 kWh
#
# Duración de la misión: 709 días
# Superficie de paneles solares: 36 m²
# Carga útil: 1111 kg
# Consumo diario: 13.468769729707128 kWh
#
# Duración de la misión: 789 días
# Superficie de paneles solares: 62 m²
# Carga útil: 950 kg
# Consumo diario: 14.455876559299188 kWh
#
# Duración de la misión: 279 días
# Superficie de paneles solares: 12 m²
# Carga útil: 1487 kg
# Consumo diario: 9.437607282260435 kWh
#
# Duración de la misión: 843 días
# Superficie de paneles solares: 21 m²
# Carga útil: 980 kg
# Consumo diario: 15.878514187449264 kWh
#
# Duración de la misión: 211 días
# Superficie de paneles solares: 17 m²
# Carga útil: 915 kg
# Consumo diario: 8.612326905638039 kWh
#
# Duración de la misión: 218 días
# Superficie de paneles solares: 53 m²
# Carga útil: 1115 kg
# Consumo diario: 10.747398107442743 kWh
#
# Duración de la misión: 696 días
# Superficie de paneles solares: 56 m²
# Carga útil: 715 kg
# Consumo diario: 12.694057388329298 kWh
#
# Duración de la misión: 549 días
# Superficie de paneles solares: 12 m²
# Carga útil: 1274 kg
# Consumo diario: 13.21457335845371 kWh
#
# Duración de la misión: 599 días
# Superficie de paneles solares: 85 m²
# Carga útil: 390 kg
# Consumo diario: 11.860489781627873 kWh
#
# Duración de la misión: 773 días
# Superficie de paneles solares: 47 m²
# Carga útil: 211 kg
# Consumo diario: 15.028844611281672 kWh
#
# Duración de la misión: 969 días
# Superficie de paneles solares: 26 m²
# Carga útil: 1879 kg
# Consumo diario: 18.160616638450826 kWh
#
# Duración de la misión: 488 días
# Superficie de paneles solares: 52 m²
# Carga útil: 1341 kg
# Consumo diario: 12.87760500359034 kWh
#
# Duración de la misión: 806 días
# Superficie de paneles solares: 69 m²
# Carga útil: 396 kg
# Consumo diario: 13.122916162256391 kWh
#
# Duración de la misión: 325 días
# Superficie de paneles solares: 81 m²
# Carga útil: 1033 kg
# Consumo diario: 10.15333407945509 kWh
#
# Duración de la misión: 309 días
# Superficie de paneles solares: 78 m²
# Carga útil: 1290 kg
# Consumo diario: 10.140560572633927 kWh
#
# Duración de la misión: 207 días
# Superficie de paneles solares: 43 m²
# Carga útil: 1867 kg
# Consumo diario: 10.709737445747443 kWh
#
# Duración de la misión: 483 días
# Superficie de paneles solares: 96 m²
# Carga útil: 1761 kg
# Consumo diario: 11.88495475460901 kWh
#
# Duración de la misión: 577 días
# Superficie de paneles solares: 32 m²
# Carga útil: 683 kg
# Consumo diario: 11.03921442154536 kWh
#
# Duración de la misión: 312 días
# Superficie de paneles solares: 85 m²
# Carga útil: 1669 kg
# Consumo diario: 14.36306716924041 kWh
#
# Duración de la misión: 893 días
# Superficie de paneles solares: 15 m²
# Carga útil: 1055 kg
# Consumo diario: 16.381555550940508 kWh
#
# Duración de la misión: 634 días
# Superficie de paneles solares: 27 m²
# Carga útil: 1684 kg
# Consumo diario: 13.721142921571763 kWh
#
# Duración de la misión: 931 días
# Superficie de paneles solares: 22 m²
# Carga útil: 1847 kg
# Consumo diario: 18.43876607446662 kWh
#
# Duración de la misión: 928 días
# Superficie de paneles solares: 24 m²
# Carga útil: 712 kg
# Consumo diario: 15.570177035483958 kWh
#
# Duración de la misión: 510 días
# Superficie de paneles solares: 20 m²
# Carga útil: 1172 kg
# Consumo diario: 12.177612509991047 kWh
#
# Duración de la misión: 119 días
# Superficie de paneles solares: 27 m²
# Carga útil: 514 kg
# Consumo diario: 6.662672781180984 kWh
#
# Duración de la misión: 486 días
# Superficie de paneles solares: 63 m²
# Carga útil: 1128 kg
# Consumo diario: 12.271429327668466 kWh
#
# Duración de la misión: 712 días
# Superficie de paneles solares: 84 m²
# Carga útil: 772 kg
# Consumo diario: 13.717155347577869 kWh
#
# Duración de la misión: 762 días
# Superficie de paneles solares: 88 m²
# Carga útil: 1626 kg
# Consumo diario: 16.18849426167331 kWh
#
# Duración de la misión: 866 días
# Superficie de paneles solares: 54 m²
# Carga útil: 526 kg
# Consumo diario: 17.526083863264784 kWh
#
# Duración de la misión: 305 días
# Superficie de paneles solares: 32 m²
# Carga útil: 1356 kg
# Consumo diario: 11.147846552556501 kWh
#
# Duración de la misión: 614 días
# Superficie de paneles solares: 35 m²
# Carga útil: 288 kg
# Consumo diario: 10.603588528016584 kWh
#
# Duración de la misión: 183 días
# Superficie de paneles solares: 85 m²
# Carga útil: 392 kg
# Consumo diario: 8.09414340339161 kWh
#
# Duración de la misión: 146 días
# Superficie de paneles solares: 72 m²
# Carga útil: 378 kg
# Consumo diario: 8.143438481558182 kWh
#
# Duración de la misión: 820 días
# Superficie de paneles solares: 91 m²
# Carga útil: 631 kg
# Consumo diario: 13.99047519255005 kWh
#
# Duración de la misión: 981 días
# Superficie de paneles solares: 62 m²
# Carga útil: 1603 kg
# Consumo diario: 18.068466798356244 kWh
#
# Duración de la misión: 654 días
# Superficie de paneles solares: 80 m²
# Carga útil: 1530 kg
# Consumo diario: 14.348022621793115 kWh
#
# Duración de la misión: 221 días
# Superficie de paneles solares: 39 m²
# Carga útil: 1125 kg
# Consumo diario: 10.931491972993157 kWh
#
# Duración de la misión: 850 días
# Superficie de paneles solares: 51 m²
# Carga útil: 1611 kg
# Consumo diario: 16.89851242137245 kWh
#
# Duración de la misión: 446 días
# Superficie de paneles solares: 32 m²
# Carga útil: 679 kg
# Consumo diario: 10.446085418678711 kWh
#
# Duración de la misión: 490 días
# Superficie de paneles solares: 53 m²
# Carga útil: 497 kg
# Consumo diario: 12.621350214164185 kWh
#
# Duración de la misión: 475 días
# Superficie de paneles solares: 40 m²
# Carga útil: 861 kg
# Consumo diario: 12.335828013698189 kWh
#
# Duración de la misión: 763 días
# Superficie de paneles solares: 39 m²
# Carga útil: 981 kg
# Consumo diario: 13.53910148929605 kWh
#
# Duración de la misión: 441 días
# Superficie de paneles solares: 31 m²
# Carga útil: 734 kg
# Consumo diario: 12.178044594698958 kWh
#
# Duración de la misión: 703 días
# Superficie de paneles solares: 92 m²
# Carga útil: 1737 kg
# Consumo diario: 16.681411888977696 kWh
#
# Duración de la misión: 532 días
# Superficie de paneles solares: 51 m²
# Carga útil: 1163 kg
# Consumo diario: 14.389934526167792 kWh
#
# Duración de la misión: 540 días
# Superficie de paneles solares: 68 m²
# Carga útil: 564 kg
# Consumo diario: 11.231429046465292 kWh
#
# Duración de la misión: 823 días
# Superficie de paneles solares: 78 m²
# Carga útil: 1339 kg
# Consumo diario: 15.210576176699725 kWh
#
# Duración de la misión: 259 días
# Superficie de paneles solares: 76 m²
# Carga útil: 263 kg
# Consumo diario: 8.898350342417661 kWh
#
# Duración de la misión: 282 días
# Superficie de paneles solares: 55 m²
# Carga útil: 1749 kg
# Consumo diario: 11.388397521229997 kWh
#
# Duración de la misión: 957 días
# Superficie de paneles solares: 65 m²
# Carga útil: 1345 kg
# Consumo diario: 19.080646157646804 kWh
#
# Duración de la misión: 185 días
# Superficie de paneles solares: 62 m²
# Carga útil: 352 kg
# Consumo diario: 5.981959744346758 kWh
#
# Duración de la misión: 751 días
# Superficie de paneles solares: 22 m²
# Carga útil: 1927 kg
# Consumo diario: 15.845720157633727 kWh
#
# Duración de la misión: 962 días
# Superficie de paneles solares: 46 m²
# Carga útil: 1268 kg
# Consumo diario: 17.7935338108977 kWh
#
# Duración de la misión: 996 días
# Superficie de paneles solares: 81 m²
# Carga útil: 1876 kg
# Consumo diario: 18.74478209287626 kWh
#
# Duración de la misión: 951 días
# Superficie de paneles solares: 74 m²
# Carga útil: 1262 kg
# Consumo diario: 16.362859722603417 kWh
#
# Duración de la misión: 568 días
# Superficie de paneles solares: 65 m²
# Carga útil: 501 kg
# Consumo diario: 12.837312036106697 kWh
#
# Duración de la misión: 254 días
# Superficie de paneles solares: 10 m²
# Carga útil: 1230 kg
# Consumo diario: 7.7087104914019005 kWh
#
# Duración de la misión: 711 días
# Superficie de paneles solares: 57 m²
# Carga útil: 1509 kg
# Consumo diario: 15.541890285372693 kWh
#
# Duración de la misión: 787 días
# Superficie de paneles solares: 56 m²
# Carga útil: 1085 kg
# Consumo diario: 12.976761723195258 kWh
#
# Duración de la misión: 225 días
# Superficie de paneles solares: 93 m²
# Carga útil: 1721 kg
# Consumo diario: 9.110405600546057 kWh
#
# Duración de la misión: 207 días
# Superficie de paneles solares: 74 m²
# Carga útil: 357 kg
# Consumo diario: 8.15235661270066 kWh
#
# Duración de la misión: 755 días
# Superficie de paneles solares: 47 m²
# Carga útil: 1858 kg
# Consumo diario: 17.079763689966214 kWh
#
# Duración de la misión: 796 días
# Superficie de paneles solares: 75 m²
# Carga útil: 800 kg
# Consumo diario: 14.792878020137168 kWh
#
# Duración de la misión: 835 días
# Superficie de paneles solares: 78 m²
# Carga útil: 1342 kg
# Consumo diario: 15.170654735260618 kWh
#
# Duración de la misión: 343 días
# Superficie de paneles solares: 57 m²
# Carga útil: 765 kg
# Consumo diario: 9.80747746754764 kWh
#
# Duración de la misión: 965 días
# Superficie de paneles solares: 23 m²
# Carga útil: 355 kg
# Consumo diario: 14.30146391802159 kWh
#
# Duración de la misión: 942 días
# Superficie de paneles solares: 76 m²
# Carga útil: 889 kg
# Consumo diario: 17.679455547658975 kWh
#
# Duración de la misión: 258 días
# Superficie de paneles solares: 59 m²
# Carga útil: 1908 kg
# Consumo diario: 11.598306191831194 kWh
#
# Duración de la misión: 942 días
# Superficie de paneles solares: 65 m²
# Carga útil: 1062 kg
# Consumo diario: 16.55542605556066 kWh
#
# Duración de la misión: 686 días
# Superficie de paneles solares: 98 m²
# Carga útil: 208 kg
# Consumo diario: 13.117820066890062 kWh
#
# Duración de la misión: 745 días
# Superficie de paneles solares: 48 m²
# Carga útil: 413 kg
# Consumo diario: 15.603653100346085 kWh
#
# Duración de la misión: 890 días
# Superficie de paneles solares: 67 m²
# Carga útil: 420 kg
# Consumo diario: 16.34425436151714 kWh
#
# Duración de la misión: 209 días
# Superficie de paneles solares: 12 m²
# Carga útil: 1434 kg
# Consumo diario: 10.065880444343033 kWh
#
# Duración de la misión: 186 días
# Superficie de paneles solares: 50 m²
# Carga útil: 1500 kg
# Consumo diario: 8.60835278589386 kWh
#
# Duración de la misión: 842 días
# Superficie de paneles solares: 97 m²
# Carga útil: 1025 kg
# Consumo diario: 14.675863709974575 kWh
#
# Duración de la misión: 110 días
# Superficie de paneles solares: 37 m²
# Carga útil: 1127 kg
# Consumo diario: 8.630274179328554 kWh
#
# Duración de la misión: 926 días
# Superficie de paneles solares: 59 m²
# Carga útil: 399 kg
# Consumo diario: 12.747896563367355 kWh
#
# Duración de la misión: 139 días
# Superficie de paneles solares: 89 m²
# Carga útil: 1432 kg
# Consumo diario: 9.713385771716613 kWh
#
# Duración de la misión: 355 días
# Superficie de paneles solares: 13 m²
# Carga útil: 391 kg
# Consumo diario: 9.470241432058682 kWh
#
# Duración de la misión: 660 días
# Superficie de paneles solares: 18 m²
# Carga útil: 1425 kg
# Consumo diario: 14.980064705601468 kWh
#
# Duración de la misión: 907 días
# Superficie de paneles solares: 32 m²
# Carga útil: 633 kg
# Consumo diario: 15.156388586168541 kWh
#
# Duración de la misión: 868 días
# Superficie de paneles solares: 79 m²
# Carga útil: 1655 kg
# Consumo diario: 16.596258827775426 kWh
#
# Duración de la misión: 278 días
# Superficie de paneles solares: 36 m²
# Carga útil: 1381 kg
# Consumo diario: 10.276161208084622 kWh
#
# Duración de la misión: 104 días
# Superficie de paneles solares: 10 m²
# Carga útil: 481 kg
# Consumo diario: 5.008939628945844 kWh
#
# Duración de la misión: 146 días
# Superficie de paneles solares: 98 m²
# Carga útil: 1642 kg
# Consumo diario: 8.261814602557179 kWh
#
# Duración de la misión: 359 días
# Superficie de paneles solares: 86 m²
# Carga útil: 640 kg
# Consumo diario: 10.61943389972774 kWh
#
# Duración de la misión: 151 días
# Superficie de paneles solares: 97 m²
# Carga útil: 1870 kg
# Consumo diario: 10.447790081941852 kWh
#
# Duración de la misión: 861 días
# Superficie de paneles solares: 72 m²
# Carga útil: 1675 kg
# Consumo diario: 16.89086206527386 kWh
#
# Duración de la misión: 854 días
# Superficie de paneles solares: 20 m²
# Carga útil: 424 kg
# Consumo diario: 14.289915529129875 kWh
#
# Duración de la misión: 585 días
# Superficie de paneles solares: 77 m²
# Carga útil: 1186 kg
# Consumo diario: 12.38460177617254 kWh
#
# Duración de la misión: 667 días
# Superficie de paneles solares: 50 m²
# Carga útil: 479 kg
# Consumo diario: 11.147463487434983 kWh
#
# Duración de la misión: 147 días
# Superficie de paneles solares: 27 m²
# Carga útil: 228 kg
# Consumo diario: 7.729585019378602 kWh
#
# Duración de la misión: 343 días
# Superficie de paneles solares: 57 m²
# Carga útil: 1964 kg
# Consumo diario: 10.97581848462296 kWh
#
# Duración de la misión: 558 días
# Superficie de paneles solares: 14 m²
# Carga útil: 326 kg
# Consumo diario: 11.706697088463201 kWh
#
# Duración de la misión: 654 días
# Superficie de paneles solares: 29 m²
# Carga útil: 1791 kg
# Consumo diario: 13.29109417415247 kWh
#
# Duración de la misión: 470 días
# Superficie de paneles solares: 25 m²
# Carga útil: 868 kg
# Consumo diario: 10.902099761626445 kWh
#
# Duración de la misión: 182 días
# Superficie de paneles solares: 43 m²
# Carga útil: 1964 kg
# Consumo diario: 10.093716723312445 kWh
#
# Duración de la misión: 588 días
# Superficie de paneles solares: 80 m²
# Carga útil: 658 kg
# Consumo diario: 12.524662002282481 kWh
#
# Duración de la misión: 672 días
# Superficie de paneles solares: 50 m²
# Carga útil: 461 kg
# Consumo diario: 13.962661655528166 kWh
#
# Duración de la misión: 587 días
# Superficie de paneles solares: 37 m²
# Carga útil: 953 kg
# Consumo diario: 13.843222416571985 kWh
#
# Duración de la misión: 620 días
# Superficie de paneles solares: 33 m²
# Carga útil: 1368 kg
# Consumo diario: 15.050592444577378 kWh
#
# Duración de la misión: 242 días
# Superficie de paneles solares: 23 m²
# Carga útil: 1030 kg
# Consumo diario: 9.828775894046295 kWh
#
# Duración de la misión: 557 días
# Superficie de paneles solares: 92 m²
# Carga útil: 1053 kg
# Consumo diario: 14.752980529053753 kWh
#
# Duración de la misión: 976 días
# Superficie de paneles solares: 22 m²
# Carga útil: 1906 kg
# Consumo diario: 19.648240157466386 kWh
#
# Duración de la misión: 350 días
# Superficie de paneles solares: 65 m²
# Carga útil: 970 kg
# Consumo diario: 10.773070372618255 kWh
#
# Duración de la misión: 460 días
# Superficie de paneles solares: 67 m²
# Carga útil: 1948 kg
# Consumo diario: 12.662631194050597 kWh
#
# Duración de la misión: 470 días
# Superficie de paneles solares: 85 m²
# Carga útil: 591 kg
# Consumo diario: 8.809016564008708 kWh
#
# Duración de la misión: 641 días
# Superficie de paneles solares: 38 m²
# Carga útil: 1856 kg
# Consumo diario: 14.828808413351238 kWh
#
# Duración de la misión: 132 días
# Superficie de paneles solares: 52 m²
# Carga útil: 1053 kg
# Consumo diario: 9.531993369907298 kWh
#
# Duración de la misión: 185 días
# Superficie de paneles solares: 61 m²
# Carga útil: 831 kg
# Consumo diario: 8.104921763649676 kWh
#
# Duración de la misión: 609 días
# Superficie de paneles solares: 59 m²
# Carga útil: 1366 kg
# Consumo diario: 14.007325649415382 kWh
#
# Duración de la misión: 654 días
# Superficie de paneles solares: 38 m²
# Carga útil: 643 kg
# Consumo diario: 13.889851532734358 kWh
#
# Duración de la misión: 808 días
# Superficie de paneles solares: 27 m²
# Carga útil: 976 kg
# Consumo diario: 15.038339062362269 kWh
#
# Duración de la misión: 573 días
# Superficie de paneles solares: 42 m²
# Carga útil: 1931 kg
# Consumo diario: 16.025214506606172 kWh
#
# Duración de la misión: 561 días
# Superficie de paneles solares: 60 m²
# Carga útil: 1795 kg
# Consumo diario: 14.780777095329796 kWh
#
# Duración de la misión: 865 días
# Superficie de paneles solares: 55 m²
# Carga útil: 1520 kg
# Consumo diario: 15.910517603274581 kWh
#
# Duración de la misión: 568 días
# Superficie de paneles solares: 32 m²
# Carga útil: 766 kg
# Consumo diario: 11.360462810814232 kWh
#
# Duración de la misión: 445 días
# Superficie de paneles solares: 54 m²
# Carga útil: 274 kg
# Consumo diario: 10.663585236313429 kWh
#
# Duración de la misión: 204 días
# Superficie de paneles solares: 88 m²
# Carga útil: 1715 kg
# Consumo diario: 10.836531407237231 kWh
#
# Duración de la misión: 169 días
# Superficie de paneles solares: 35 m²
# Carga útil: 1217 kg
# Consumo diario: 8.815326944453586 kWh
#
# Duración de la misión: 400 días
# Superficie de paneles solares: 75 m²
# Carga útil: 765 kg
# Consumo diario: 8.698593915784876 kWh
#
# Duración de la misión: 912 días
# Superficie de paneles solares: 11 m²
# Carga útil: 986 kg
# Consumo diario: 14.596939169772797 kWh
#
# Duración de la misión: 844 días
# Superficie de paneles solares: 47 m²
# Carga útil: 870 kg
# Consumo diario: 16.075184981971685 kWh
#
# Duración de la misión: 315 días
# Superficie de paneles solares: 64 m²
# Carga útil: 1403 kg
# Consumo diario: 7.991471162158348 kWh
#
# Duración de la misión: 207 días
# Superficie de paneles solares: 55 m²
# Carga útil: 1925 kg
# Consumo diario: 13.340415012247401 kWh
#
# Duración de la misión: 504 días
# Superficie de paneles solares: 79 m²
# Carga útil: 964 kg
# Consumo diario: 12.433080209500305 kWh
#
# Duración de la misión: 379 días
# Superficie de paneles solares: 22 m²
# Carga útil: 1469 kg
# Consumo diario: 11.430676637302364 kWh
#
# Duración de la misión: 933 días
# Superficie de paneles solares: 67 m²
# Carga útil: 800 kg
# Consumo diario: 16.72080612169008 kWh
#
# Duración de la misión: 109 días
# Superficie de paneles solares: 78 m²
# Carga útil: 1145 kg
# Consumo diario: 9.048326018107996 kWh
#
# Duración de la misión: 740 días
# Superficie de paneles solares: 24 m²
# Carga útil: 951 kg
# Consumo diario: 15.93093694762399 kWh
#
# Duración de la misión: 852 días
# Superficie de paneles solares: 96 m²
# Carga útil: 1200 kg
# Consumo diario: 15.032304344285441 kWh
#
# Duración de la misión: 821 días
# Superficie de paneles solares: 99 m²
# Carga útil: 1371 kg
# Consumo diario: 17.35582139206656 kWh
#
# Duración de la misión: 227 días
# Superficie de paneles solares: 85 m²
# Carga útil: 906 kg
# Consumo diario: 10.53704557627071 kWh
#
# Duración de la misión: 851 días
# Superficie de paneles solares: 77 m²
# Carga útil: 274 kg
# Consumo diario: 15.622718021669904 kWh
#
# Duración de la misión: 490 días
# Superficie de paneles solares: 92 m²
# Carga útil: 471 kg
# Consumo diario: 9.900877904075042 kWh
#
# Duración de la misión: 319 días
# Superficie de paneles solares: 91 m²
# Carga útil: 1893 kg
# Consumo diario: 10.410240927819485 kWh
#
# Duración de la misión: 140 días
# Superficie de paneles solares: 27 m²
# Carga útil: 725 kg
# Consumo diario: 7.311228682382257 kWh
#
# Duración de la misión: 996 días
# Superficie de paneles solares: 62 m²
# Carga útil: 1501 kg
# Consumo diario: 17.17543422489583 kWh
#
# Duración de la misión: 543 días
# Superficie de paneles solares: 34 m²
# Carga útil: 638 kg
# Consumo diario: 10.879770533636046 kWh
#
# Duración de la misión: 868 días
# Superficie de paneles solares: 67 m²
# Carga útil: 1201 kg
# Consumo diario: 15.828622431051986 kWh
#
# Duración de la misión: 684 días
# Superficie de paneles solares: 81 m²
# Carga útil: 1573 kg
# Consumo diario: 15.189388240619945 kWh
#
# Duración de la misión: 752 días
# Superficie de paneles solares: 42 m²
# Carga útil: 1538 kg
# Consumo diario: 16.258665970385483 kWh
#
# Duración de la misión: 585 días
# Superficie de paneles solares: 93 m²
# Carga útil: 1720 kg
# Consumo diario: 14.846533442751264 kWh
#
# Duración de la misión: 578 días
# Superficie de paneles solares: 79 m²
# Carga útil: 1440 kg
# Consumo diario: 13.57290582894749 kWh
#
# Duración de la misión: 866 días
# Superficie de paneles solares: 48 m²
# Carga útil: 1837 kg
# Consumo diario: 16.58047241964262 kWh
#
# Duración de la misión: 208 días
# Superficie de paneles solares: 86 m²
# Carga útil: 891 kg
# Consumo diario: 7.973202686769081 kWh
#
# Duración de la misión: 406 días
# Superficie de paneles solares: 11 m²
# Carga útil: 917 kg
# Consumo diario: 11.228295128497715 kWh
#
# Duración de la misión: 666 días
# Superficie de paneles solares: 66 m²
# Carga útil: 904 kg
# Consumo diario: 14.368184564019963 kWh
#
# Duración de la misión: 259 días
# Superficie de paneles solares: 38 m²
# Carga útil: 544 kg
# Consumo diario: 8.518351692577983 kWh
#
# Duración de la misión: 647 días
# Superficie de paneles solares: 93 m²
# Carga útil: 1443 kg
# Consumo diario: 14.543973587486102 kWh
#
# Duración de la misión: 503 días
# Superficie de paneles solares: 22 m²
# Carga útil: 1277 kg
# Consumo diario: 12.516019744015596 kWh
#
# Duración de la misión: 473 días
# Superficie de paneles solares: 35 m²
# Carga útil: 506 kg
# Consumo diario: 10.931843392837443 kWh
#
# Duración de la misión: 732 días
# Superficie de paneles solares: 74 m²
# Carga útil: 1967 kg
# Consumo diario: 17.590186100012172 kWh
#
# Duración de la misión: 891 días
# Superficie de paneles solares: 52 m²
# Carga útil: 1972 kg
# Consumo diario: 18.217454337839072 kWh
#
# Duración de la misión: 785 días
# Superficie de paneles solares: 56 m²
# Carga útil: 1497 kg
# Consumo diario: 14.687652339734669 kWh
#
# Duración de la misión: 661 días
# Superficie de paneles solares: 80 m²
# Carga útil: 1029 kg
# Consumo diario: 14.382396482630657 kWh
#
# Duración de la misión: 880 días
# Superficie de paneles solares: 55 m²
# Carga útil: 1518 kg
# Consumo diario: 15.6593852805707 kWh
#
# Duración de la misión: 684 días
# Superficie de paneles solares: 59 m²
# Carga útil: 1930 kg
# Consumo diario: 17.31111614849962 kWh
#
# Duración de la misión: 688 días
# Superficie de paneles solares: 19 m²
# Carga útil: 1972 kg
# Consumo diario: 16.07303612230694 kWh
#
# Duración de la misión: 839 días
# Superficie de paneles solares: 76 m²
# Carga útil: 1946 kg
# Consumo diario: 16.85808624758016 kWh
#
# Duración de la misión: 774 días
# Superficie de paneles solares: 10 m²
# Carga útil: 422 kg
# Consumo diario: 12.302930793154168 kWh
#
# Duración de la misión: 557 días
# Superficie de paneles solares: 79 m²
# Carga útil: 1933 kg
# Consumo diario: 15.248601287753644 kWh
#
# Duración de la misión: 540 días
# Superficie de paneles solares: 87 m²
# Carga útil: 1036 kg
# Consumo diario: 10.697037940357873 kWh
#
# Duración de la misión: 317 días
# Superficie de paneles solares: 47 m²
# Carga útil: 333 kg
# Consumo diario: 10.110447216941239 kWh
#
# Duración de la misión: 814 días
# Superficie de paneles solares: 29 m²
# Carga útil: 1199 kg
# Consumo diario: 14.901384716897764 kWh
#
# Duración de la misión: 339 días
# Superficie de paneles solares: 93 m²
# Carga útil: 1000 kg
# Consumo diario: 10.838099363936204 kWh
#
# Duración de la misión: 840 días
# Superficie de paneles solares: 14 m²
# Carga útil: 870 kg
# Consumo diario: 15.678034439928252 kWh
#
# Duración de la misión: 432 días
# Superficie de paneles solares: 19 m²
# Carga útil: 1876 kg
# Consumo diario: 11.64826556460094 kWh
#
# Duración de la misión: 707 días
# Superficie de paneles solares: 69 m²
# Carga útil: 1592 kg
# Consumo diario: 14.447401095692628 kWh
#
# Duración de la misión: 765 días
# Superficie de paneles solares: 76 m²
# Carga útil: 908 kg
# Consumo diario: 14.707644521676752 kWh
#
# Duración de la misión: 820 días
# Superficie de paneles solares: 91 m²
# Carga útil: 622 kg
# Consumo diario: 15.895178849021063 kWh
#
# Duración de la misión: 310 días
# Superficie de paneles solares: 87 m²
# Carga útil: 998 kg
# Consumo diario: 10.364913447678601 kWh
#
# Duración de la misión: 104 días
# Superficie de paneles solares: 33 m²
# Carga útil: 1419 kg
# Consumo diario: 9.34913629339993 kWh
#
# Duración de la misión: 783 días
# Superficie de paneles solares: 46 m²
# Carga útil: 1459 kg
# Consumo diario: 17.11064263980334 kWh
#
# Duración de la misión: 906 días
# Superficie de paneles solares: 32 m²
# Carga útil: 627 kg
# Consumo diario: 12.90121966907051 kWh
#
# Duración de la misión: 571 días
# Superficie de paneles solares: 41 m²
# Carga útil: 1603 kg
# Consumo diario: 13.510730734550668 kWh
#
# Duración de la misión: 868 días
# Superficie de paneles solares: 73 m²
# Carga útil: 1262 kg
# Consumo diario: 15.893516023804057 kWh
#
# Duración de la misión: 203 días
# Superficie de paneles solares: 34 m²
# Carga útil: 1189 kg
# Consumo diario: 8.294611958078153 kWh
#
# Duración de la misión: 897 días
# Superficie de paneles solares: 71 m²
# Carga útil: 352 kg
# Consumo diario: 15.198507375286088 kWh
#
# Duración de la misión: 504 días
# Superficie de paneles solares: 74 m²
# Carga útil: 964 kg
# Consumo diario: 14.020684981945891 kWh
#
# Duración de la misión: 826 días
# Superficie de paneles solares: 67 m²
# Carga útil: 733 kg
# Consumo diario: 14.388674837931493 kWh
#
# Duración de la misión: 580 días
# Superficie de paneles solares: 22 m²
# Carga útil: 414 kg
# Consumo diario: 9.897328394492781 kWh
#
# Duración de la misión: 617 días
# Superficie de paneles solares: 15 m²
# Carga útil: 906 kg
# Consumo diario: 12.59153605053719 kWh
#
# Duración de la misión: 297 días
# Superficie de paneles solares: 54 m²
# Carga útil: 819 kg
# Consumo diario: 11.27588761111952 kWh
#
# Duración de la misión: 220 días
# Superficie de paneles solares: 17 m²
# Carga útil: 320 kg
# Consumo diario: 8.427259166802791 kWh
#
# Duración de la misión: 599 días
# Superficie de paneles solares: 11 m²
# Carga útil: 743 kg
# Consumo diario: 12.65339611463694 kWh
#
# Duración de la misión: 507 días
# Superficie de paneles solares: 89 m²
# Carga útil: 817 kg
# Consumo diario: 11.3802082957134 kWh
#
# Duración de la misión: 898 días
# Superficie de paneles solares: 96 m²
# Carga útil: 1932 kg
# Consumo diario: 16.941576905207487 kWh
#
# Duración de la misión: 776 días
# Superficie de paneles solares: 98 m²
# Carga útil: 712 kg
# Consumo diario: 14.102412230314878 kWh
#
# Duración de la misión: 447 días
# Superficie de paneles solares: 31 m²
# Carga útil: 1208 kg
# Consumo diario: 12.368066835525525 kWh
#
# Duración de la misión: 392 días
# Superficie de paneles solares: 37 m²
# Carga útil: 1153 kg
# Consumo diario: 8.661255658179432 kWh
#
# Duración de la misión: 294 días
# Superficie de paneles solares: 63 m²
# Carga útil: 1315 kg
# Consumo diario: 9.856125175963516 kWh
#
# Duración de la misión: 688 días
# Superficie de paneles solares: 86 m²
# Carga útil: 634 kg
# Consumo diario: 13.983807896314337 kWh
#
# Duración de la misión: 259 días
# Superficie de paneles solares: 23 m²
# Carga útil: 824 kg
# Consumo diario: 9.62310311939774 kWh
#
# Duración de la misión: 886 días
# Superficie de paneles solares: 15 m²
# Carga útil: 1210 kg
# Consumo diario: 16.667703141262017 kWh
#
# Duración de la misión: 626 días
# Superficie de paneles solares: 80 m²
# Carga útil: 1342 kg
# Consumo diario: 14.569085201248154 kWh
#
# Duración de la misión: 494 días
# Superficie de paneles solares: 95 m²
# Carga útil: 1990 kg
# Consumo diario: 13.398677081362717 kWh
#
# Duración de la misión: 330 días
# Superficie de paneles solares: 83 m²
# Carga útil: 1408 kg
# Consumo diario: 10.680592527056037 kWh
#
# Duración de la misión: 912 días
# Superficie de paneles solares: 52 m²
# Carga útil: 533 kg
# Consumo diario: 15.97680172117899 kWh
#
# Duración de la misión: 387 días
# Superficie de paneles solares: 19 m²
# Carga útil: 968 kg
# Consumo diario: 10.38122627220691 kWh
#
# Duración de la misión: 687 días
# Superficie de paneles solares: 80 m²
# Carga útil: 1122 kg
# Consumo diario: 13.868238499987099 kWh
#
# Duración de la misión: 225 días
# Superficie de paneles solares: 13 m²
# Carga útil: 1888 kg
# Consumo diario: 10.199294953083106 kWh
#
# Duración de la misión: 963 días
# Superficie de paneles solares: 36 m²
# Carga útil: 273 kg
# Consumo diario: 12.855643987613856 kWh
#
# Duración de la misión: 614 días
# Superficie de paneles solares: 15 m²
# Carga útil: 1972 kg
# Consumo diario: 14.882895345481169 kWh
#
# Duración de la misión: 509 días
# Superficie de paneles solares: 81 m²
# Carga útil: 762 kg
# Consumo diario: 11.368939348809299 kWh
#
# Duración de la misión: 866 días
# Superficie de paneles solares: 20 m²
# Carga útil: 1344 kg
# Consumo diario: 17.397173621441347 kWh
#
# Duración de la misión: 446 días
# Superficie de paneles solares: 90 m²
# Carga útil: 1456 kg
# Consumo diario: 11.461425116078551 kWh
#
# Duración de la misión: 979 días
# Superficie de paneles solares: 37 m²
# Carga útil: 1082 kg
# Consumo diario: 17.601484690709476 kWh
#
# Duración de la misión: 454 días
# Superficie de paneles solares: 23 m²
# Carga útil: 202 kg
# Consumo diario: 10.645663648089567 kWh
#
# Duración de la misión: 473 días
# Superficie de paneles solares: 87 m²
# Carga útil: 492 kg
# Consumo diario: 10.503309985636843 kWh
#
# Duración de la misión: 101 días
# Superficie de paneles solares: 34 m²
# Carga útil: 1081 kg
# Consumo diario: 6.608522052131312 kWh
#
# Duración de la misión: 469 días
# Superficie de paneles solares: 48 m²
# Carga útil: 1192 kg
# Consumo diario: 11.051719718352672 kWh
#
# Duración de la misión: 802 días
# Superficie de paneles solares: 57 m²
# Carga útil: 668 kg
# Consumo diario: 15.484018857349302 kWh
#
# Duración de la misión: 637 días
# Superficie de paneles solares: 31 m²
# Carga útil: 1845 kg
# Consumo diario: 14.137113558104733 kWh
#
# Duración de la misión: 531 días
# Superficie de paneles solares: 40 m²
# Carga útil: 610 kg
# Consumo diario: 11.812586982919298 kWh
#
# Duración de la misión: 322 días
# Superficie de paneles solares: 93 m²
# Carga útil: 1068 kg
# Consumo diario: 9.236464124729476 kWh
#
# Duración de la misión: 143 días
# Superficie de paneles solares: 87 m²
# Carga útil: 1480 kg
# Consumo diario: 9.448274330935448 kWh

# %% [markdown]
# 3. Procesar los datos con SatelliteDataProcessor
#
# Convierte la lista de objetos Satellite en un DataFrame de pandas.
# Añade una columna nueva para la métrica eficiencia_energia: Esta métrica mide cuánto consume el satélite por cada metro cuadrado de panel solar.

# %%
class SatelliteDataProcessor:
  def __init__(self, satellites):
    self.satellites = satellites
    self.df = pd.DataFrame([vars(satellite) for satellite in self.satellites])
  def calcula_eficiencia(self):
      self.df['eficiencia_energia'] = self.df['consumo_diario_kWh'] / self.df['paneles_sol_m2']
  def get_dataframe(self):
    return self.df
  def __str__(self):
    return str(self.df)

# %%
satelites = ds1.generate()
processor = SatelliteDataProcessor(satelites)
print(processor)
processor.calcula_eficiencia()
print(processor)
df = processor.get_dataframe()
df
# Out:
#      duracion_mision_dias  paneles_sol_m2  carga_util_kg  consumo_diario_kWh
# 0                     643              14            774           13.256144
# 1                     224              18            216            8.449767
# 2                     834              12            476           12.044731
# 3                     199              52            634            9.445725
# 4                     307              63           1437           11.043035
# ..                    ...             ...            ...                 ...
# 295                   704              73            867           14.233706
# 296                   666              83            864           12.101607
# 297                   555              54           1027           11.176864
# 298                   638              77            829           14.163044
# 299                   218              43           1328            7.575585
#
# [300 rows x 4 columns]
#      duracion_mision_dias  paneles_sol_m2  carga_util_kg  consumo_diario_kWh  \
# 0                     643              14            774           13.256144
# 1                     224              18            216            8.449767
# 2                     834              12            476           12.044731
# 3                     199              52            634            9.445725
# 4                     307              63           1437           11.043035
# ..                    ...             ...            ...                 ...
# 295                   704              73            867           14.233706
# 296                   666              83            864           12.101607
# 297                   555              54           1027           11.176864
# 298                   638              77            829           14.163044
# 299                   218              43           1328            7.575585
#
#      eficiencia_energia
# 0              0.946867
# 1              0.469432
# 2              1.003728
# 3              0.181649
# 4              0.175286
# ..                  ...
# 295            0.194982
# 296            0.145802
# 297            0.206979
# 298            0.183936
# 299            0.176176
#
# [300 rows x 5 columns]
#      duracion_mision_dias  paneles_sol_m2  carga_util_kg  consumo_diario_kWh  \
# 0                     643              14            774           13.256144
# 1                     224              18            216            8.449767
# 2                     834              12            476           12.044731
# 3                     199              52            634            9.445725
# 4                     307              63           1437           11.043035
# ..                    ...             ...            ...                 ...
# 295                   704              73            867           14.233706
# 296                   666              83            864           12.101607
# 297                   555              54           1027           11.176864
# 298                   638              77            829           14.163044
# 299                   218              43           1328            7.575585
#
#      eficiencia_energia
# 0              0.946867
# 1              0.469432
# 2              1.003728
# 3              0.181649
# 4              0.175286
# ..                  ...
# 295            0.194982
# 296            0.145802
# 297            0.206979
# 298            0.183936
# 299            0.176176
#
# [300 rows x 5 columns]

# %% [markdown]
# 4. Aplicar regresión lineal con EnergyConsumptionRegressor
#
# Esta clase debe aplicar el modelo de regresión lineal para predecir el consumo energético a partir de la duración de la misión. Debes:
#
# Entrenar el modelo con duracion_mision_dias como entrada (X) y consumo_diario como salida (y).
#
# Calcular el R² del modelo (r2_score) y mostrar los coeficientes:
#
# y_pred=(coef⋅duracion_mision)+intercepto

# %%
class EnergyConsumptionRegressor:
  def __init__(self, satellites):
    self.model = LinearRegression()
    self.data = satellites
    self._processor = None
    self._coeficientes = float(0)
    self._intercepto = float(0)
    self._r2 = float(0)

  def _prepara_datos(self, datos) -> tuple:
    """
    Prepara los datos de entrada para el modelo de regresión.
    """
    X = datos['duracion_mision_dias']
    Y = datos['consumo_diario_kWh']
    return X, Y

  def fit(self):
    """
    Entrena el modelo de regresión.
    """
    self._processor = SatelliteDataProcessor(self.data)
    self._processor.calcula_eficiencia()
    X, Y = self._prepara_datos(self._processor.get_dataframe())

    #print("lista->",X)
    # convertimos la lista X en un array unidimensional de aridad n (n, )
    #print("array->",np.array(X), "de dimensionalidad",np.shape(np.array(X)))
    # convertimos la lista X en un array bidimensional de n elemento en la
    # primera dimensio y 1 elemento en la segunda dimensión (n, 1)
    #print("array->",np.array(X).reshape(-1, 1), "de dimensionalidad",np.shape(np.array(X).reshape(-1, 1)))
    self.model.fit(np.array(X).reshape(-1, 1), Y)
    self.set_coeficientes(self.model.coef_[0])
    self.set_intercepto(self.model.intercept_)
    self.set_r2(r2_score(Y, self.model.predict(np.array(X).reshape(-1, 1))))

  def predict(self, horas: float) -> float:
    """
    Predice el desgaste de un vehículo.
    """
    return self.model.predict([[horas]])[0]

  def set_coeficientes(self, coeficientes):
    self._coeficientes = float(coeficientes)

  def set_intercepto(self, intercepto):
    self._intercepto = float(intercepto)

  def set_r2(self, r2):
    self._r2 = float(r2)

  def get_model(self):
    return self.model

  def get_coeficientes(self):
    return self._coeficientes

  def get_intercepto(self):
    return self._intercepto

  def get_r2(self):
    return self._r2



  def __str__(self):
    resultado = f"Modelo: y = {self._coeficientes:.4f} * x + {self._intercepto:.2f}\n"
    resultado += f"R² del modelo: {self._r2:.4f}\n"
    return resultado

# %% [markdown]
# #### test de la clase EnergyConsumptionRegressor

# %%
generator = SatelliteDatasetGenerator()
satelites = generator.generate()
ecr = EnergyConsumptionRegressor(satelites)
print(ecr)
ecr.fit()
print(ecr)
# Out:
# Modelo: y = 0.0000 * x + 0.00
# R² del modelo: 0.0000
#
# Modelo: y = 0.0101 * x + 7.06
# R² del modelo: 0.7652

# %% [markdown]
# 5. Visualizar los resultados con SatellitePlotter
#
# Muestra un gráfico con:
#
# + Puntos dispersos: consumo diario vs. duración de la misión.
# + Color por carga útil (usa un mapa de color viridis).
# + Línea de regresión en rojo.

# %%
class SatellitePlotter:
  def __init__(self, satelites):
    self.satelites = satelites

  def visualizacion(self, coef, inter):
    x = [satelite.get_duracion() for satelite in self.satelites]
    y = [satelite.get_consumo_diario() for satelite in self.satelites]
    c = [satelite.get_carga_util() for satelite in self.satelites]
    r = [coef * e + inter for e in x]

    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, c=c, cmap='viridis')
    plt.plot(x, r, color='red')
    plt.AbstractContextManager
    plt.xlabel('Duración de la misión (días)')
    plt.ylabel('Consumo diario (kWh)')
    plt.colorbar(label='Carga útil (kg)')
    plt.title('Consumo diario vs. duración de la misión')
    plt.show()

# %% [markdown]
# ## Pruebas a SatellitePlotter

# %%
sp=SatellitePlotter(satelites)
sp.visualizacion()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-454-4d128e12f170> in <cell line: 0>()
#       1 sp=SatellitePlotter(satelites)
# ----> 2 sp.visualizacion()
#
# TypeError: SatellitePlotter.visualizacion() missing 2 required positional arguments: 'coef' and 'inter'

# %% [markdown]
# 6. Ejecutar todo con la clase SatelliteAnalysisExample
#
# Una vez que has desarrollado las clases anteriores para generar, procesar, modelar y visualizar los datos, el último paso es integrar todo en una clase orquestadora que automatice el análisis completo.Esta clase debe encargarse de:
#
# Generar los datos: usando la clase SatelliteDatasetGenerator.
# Procesarlos: con SatelliteDataProcessor, que además de convertir la lista a DataFrame, añade la columna de eficiencia.
# Aplicar regresión: usando EnergyConsumptionRegressor para entrenar el modelo con la duración de la misión como predictor.
# Evaluar el modelo: imprimiendo el coeficiente de regresión, el intercepto y el R², que indica qué tan bien se ajusta el modelo a los datos.
# Visualizar los resultados: con SatellitePlotter, mostrando una gráfica clara con los datos y la predicción lineal

# %%
class SatelliteAnalysisExample:
  def __init__(self):
    self.generator = SatelliteDatasetGenerator()
    self.satelites = self.generator.generate()
    self.processor = SatelliteDataProcessor(self.satelites)
    self.processor.calcula_eficiencia()
    self.regressor = EnergyConsumptionRegressor(self.satelites)
    self.regressor.fit()
    self.plotter = SatellitePlotter(self.satelites)
  def run(self):
    print(self.regressor)
    self.plotter.visualizacion(self.regressor.get_coeficientes(), self.regressor.get_intercepto())

# %%
ejemplo = SatelliteAnalysisExample()
ejemplo.run()
# Out:
# Modelo: y = 0.0101 * x + 7.06
# R² del modelo: 0.7652
