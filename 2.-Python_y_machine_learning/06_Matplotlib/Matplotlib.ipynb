# %% [markdown]
# <a href="https://colab.research.google.com/github/luismiguelcasadodiaz/IBM_SkillsBuild_IA_325/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib
#
# ### Mi primer gráfico

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = x **2

# %%
plt.plot(x, y)
# no es necesario en Jupiter notebook poner plot.show()

# %% [markdown]
# ### Los colores de las líneas

# %% [markdown]
# [List of named colors](https://matplotlib.org/stable/gallery/color/named_colors.html)

# %%
plt.plot(x, y, 'mediumpurple') # grenn, lightgreen, mediumpurple

# %% [markdown]
# ### El título

# %%
plt.plot(x, y, 'olivedrab')
plt.title('Mi primer gráfico')
# Out:
# Text(0.5, 1.0, 'Mi primer gráfico')

# %% [markdown]
# ### Ejes: Etiquetas

# %%
plt.plot(x, y, 'olivedrab')
plt.title('Mi primer gráfico')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
# Out:
# Text(0, 0.5, 'Eje Y')

# %% [markdown]
# ### Multigráficos en el eje horizontal

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'blue')
plt.title('Mi segundo gráfico')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.subplot(1,2,2)
plt.plot(y, x, 'red')
plt.title('Mi tercer gráfico')
plt.xlabel('Eje y')
plt.ylabel('Eje x')
# Out:
# Text(0, 0.5, 'Eje x')

# %% [markdown]
# ### Multigráficos en el eje vertical

# %%
plt.subplot(2,1,1)
plt.plot(x, y, 'blue')
plt.title('Mi segundo gráfico')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.subplot(2,1,2)
plt.plot(y, x, 'red')
plt.title('Mi tercer gráfico')
plt.xlabel('Eje y')
plt.ylabel('Eje x')
# Out:
# Text(0, 0.5, 'Eje x')

# %% [markdown]
# ### Multiples gráficos (unos dentro de otros)

# %%
figura = plt.figure()
g1 = figura.add_axes([0.1, 0.1, 0.9, 0.9])
g1.plot(x, y, 'blue')
g1.set_title('Mi segundo gráfico')
g1.set_xlabel('Eje X')
g1.set_ylabel('Eje Y')
g2 = figura.add_axes([0.2, 0.5, 0.4, 0.4])
g2.plot(y, x, 'red')
g2.set_title('Mi tercer gráfico')
g2.set_xlabel('Eje y')
g2.set_ylabel('Eje x')
# Out:
# Text(0, 0.5, 'Eje x')

# %% [markdown]
# ### Matriz de gráficos

# %%
figura, graficos = plt.subplots(nrows=2, ncols=2)

# %%
figura, graficos = plt.subplots(nrows=2, ncols=2)
graficos[0,0].plot(x, y, 'blue')
graficos[0,0].set_title('gráfico upper left')
# Out:
# Text(0.5, 1.0, 'gráfico upper left')

# %%
figura, graficos = plt.subplots(nrows=2, ncols=2)
graficos[0,0].plot(x, y, 'blue')
graficos[0,0].set_title('gráfico upper left')
# Out:
# Text(0.5, 1.0, 'gráfico upper left')

# %%
figura, graficos = plt.subplots(nrows=2, ncols=2)
graficos[0,0].plot(x, y, 'red')
graficos[0,0].set_title('gráfico upper left')
graficos[0,1].plot(x, y, 'blue')
graficos[0,1].set_title('gráfico upper right')
# Out:
# Text(0.5, 1.0, 'gráfico upper right')

# %%
figura, graficos = plt.subplots(nrows=2, ncols=2)
graficos[0,0].plot(x, y, 'red')
graficos[0,0].set_title('gráfico upper left')
graficos[0,1].plot(x, y, 'blue')
graficos[0,1].set_title('gráfico upper right')
graficos[1,0].plot(x, y, 'green')
graficos[1,0].set_title('gráfico lower right')
# Out:
# Text(0.5, 1.0, 'gráfico lower right')

# %%
figura, graficos = plt.subplots(nrows=2, ncols=2)
graficos[0,0].plot(x, y, 'red')
graficos[0,0].set_title('gráfico upper left')
graficos[0,1].plot(x, y, 'blue')
graficos[0,1].set_title('gráfico upper right')
graficos[1,0].plot(x, y, 'green')
graficos[1,0].set_title('gráfico lower right')
graficos[1,1].plot(x, y, 'black')
graficos[1,1].set_title('gráfico lower right')
# Out:
# Text(0.5, 1.0, 'gráfico lower right')

# %% [markdown]
# ### Tamaño del gráfico

# %%
figura = plt.figure(figsize=(8,5))
graficos = figura.add_axes([0.1, 0.1, 0.9, 0.9])
graficos.plot(x, y, 'blue')

# %%
figura = plt.figure(figsize=(16,2))
graficos = figura.add_axes([0.1, 0.1, 0.9, 0.9])
graficos.plot(x, y, 'blue')

# %% [markdown]
# ### Dos Series de datos en la misma figura

# %%
figura = plt.figure(figsize=(6,6))
graficos = figura.add_axes([0.1, 0.1, 0.9, 0.9])
graficos.plot(x, x**2, 'red', label='Al cuadrado')
graficos.plot(x, x**3, 'green', label='Al cubo')
graficos.plot(x, x**4, 'blue', label='A la cuarta')
graficos.legend(loc = 0)

# %% [markdown]
# ### color hexadecimal del grafico

# %%
figura = plt.figure(figsize=(6,6))
graficos = figura.add_axes([0.1, 0.1, 0.9, 0.9])
graficos.plot(x, x**2, color='#ff0000', label='Al cuadrado')
graficos.plot(x, x**3, '#00ff00', label='Al cubo')
graficos.plot(x, x**4, '#0000ff', label='A la cuarta')
graficos.legend(loc = 0)

# %% [markdown]
# ### Grosor, transparencia y tipo de línea
# [Estilos de línes soportados](https://matplotlib.org/3.0.3/gallery/lines_bars_and_markers/line_styles_reference.html)

# %%
figura = plt.figure(figsize=(6,6))
graficos = figura.add_axes([0.1, 0.1, 0.9, 0.9])
graficos.plot(x, x**2, color='#ff0000', linewidth=5, alpha=0.1, linestyle='-', label='Al cuadrado') # '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
graficos.plot(x, x*3, color='#00ff00', linewidth=3, alpha=0.4, linestyle=':', label='Al cubo')
graficos.plot(x, x*4, color='#0000ff', linewidth=10, alpha=0.7, linestyle='-.', label='A la cuarta')
graficos.legend(loc = 0)

# %% [markdown]
# ### Marcadores
# [Estilos de marcadores](https://matplotlib.org/3.3.3/api/markers_api.html)

# %%
import matplotlib.markers as markers
markers.MarkerStyle.markers
x = np.linspace(0, 10, 20)
y = x **2
figura = plt.figure(figsize=(6,6))
graficos = figura.add_axes([0.1, 0.1, 0.9, 0.9])
graficos.plot(x, y, color='#ff0000', marker=markers.CARETDOWNBASE, markersize=11, linewidth=5, alpha=0.1, linestyle='-', label='Al cuadrado')
graficos.plot(x, x*2, color='#00ff00', marker='s', markersize=11, markerfacecolor='red', markeredgecolor='black',linewidth=3, alpha=1, linestyle=':', label='Al doble')
graficos.legend(loc = 0)
